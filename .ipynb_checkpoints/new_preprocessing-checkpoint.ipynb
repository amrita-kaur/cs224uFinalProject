# %%
import pandas as pd
import os
import numpy as np

# %%
raw = pd.read_csv("aita_clean.csv")

# %%
# Number of total examples
print(str(len(raw)))
# Out:
# 97628

# %%
def concatenate(df):
    df["text"] = df["title"] + " " + df["body"]

# %%
def extract_age(df):
    df["age"] = ""
    df["a1"] = ""
    df["a2"] = ""
    
    df["a1"] = df["text"].str.extract(r'(?:(?:I|[Mm]y|[Mm]ine|[Mm]e|AITA|I\'m|I\'m\sa)[\s]*(?:\(|\[)(?:F|M|f|m)?(?:,|\s)*(\d+)(?:,|\s)*(?:F|M|f|m)?(?:\)|\]))')
    df["a2"] = df["text"].str.extract(r'(?:I\'m|I\'m\sa|I\sam|I)[\s]*(\d+)')
    #(?:(?:I|[Mm]y|[Mm]ine|[Mm]e|AITA|I\'m|I\'m\sa)[\s]*(?:\(|\[)(?:F|M|f|m)?(?:,|\s)*(\d+)(?:,|\s)*(?:F|M|f|m)?(?:\)|\]))|(?:(?:I\'m|I)[\sa-zA-Z]*(\d+))
    for index,row in df.iterrows():
        if pd.notnull(df.at[index,"a1"]):
            df.at[index,"age"] = df.at[index,"a1"]
        elif pd.notnull(df.at[index,"a2"]):
            df.at[index,"age"] = df.at[index,"a2"]
            
    df["age"] = df["age"].replace({'': np.nan})
    del df["a1"]
    del df["a2"]

# %%
def extract_gender(df):
    df["gender"] = ""
    df["g1"] = ""
    df["g2"] = ""
    df["g3"] = ""
    df["g4"] = ""
    
    df["g1"] = df["text"].str.extract(r'(?:I|AITA|[Mm]y|[Mm]ine|[Mm]e)[\s]*(?:\(|\[)\d+(?:,|\s)*(F|M|f|m)(?:\)|\])')
    df["g2"] = df["text"].str.extract(r'(?:I|AITA|[Mm]y|[Mm]ine|[Mm]e)[\s]*(?:\(|\[)(?:(F|M|f|m)(?:,|\s)*\d+)(?:\)|\])')
    df["g3"] = df["text"].str.extract(r'(?:I\'m|I\'m\sa)[\sa-zA-Z]*(?:\(|\[)?\d+(?:,|\s)*(F|M|f|m)(?:\)|\])?')
    df["g4"] = df["text"].str.extract(r'(?:I\'m|I\'m\sa)[\sa-zA-Z]*(?:\(|\[)?(F|M|f|m)(?:,|\s)*\d+(?:\)|\])?')
    #(?:I|AITA|[Mm]y|[Mm]ine|[Mm]e)[\s]*(?:\(|\[)(?:\d+(?:,|\s)*(F|M|f|m)|(F|M|f|m)(?:,|\s)*\d+)(?:\)|\])|(?:I\'m|I\'m\sa)[\sa-zA-Z]*(?:\(|\[)?(?:\d+(?:,|\s)*(F|M|f|m)|(F|M|f|m)(?:,|\s)*\d+)(?:\)|\])?
    for index,row in df.iterrows():
        if pd.notnull(df.at[index,"g1"]):
            df.at[index,"gender"] = df.at[index,"g1"]
        elif pd.notnull(df.at[index,"g2"]):
            df.at[index,"gender"] = df.at[index,"g2"]
        elif pd.notnull(df.at[index,"g3"]):
            df.at[index,"gender"] = df.at[index,"g3"]
        elif pd.notnull(df.at[index,"g4"]):
            df.at[index,"gender"] = df.at[index,"g4"]
    
    df["gender"] = df["gender"].replace({'': np.nan})
    del df["g1"]
    del df["g2"]
    del df["g3"]
    del df["g4"]

# %%
concatenate(raw)
extract_age(raw)
extract_gender(raw)
print(raw)
# Out:
#            id     timestamp  \
# 0      1ytxov  1.393279e+09
# 1      1yu29c  1.393281e+09
# 2      1yu8hi  1.393285e+09
# 3      1yuc78  1.393287e+09
# 4      1yueqb  1.393288e+09
# ...       ...           ...
# 97623  ex94w5  1.580577e+09
# 97624  ex970f  1.580577e+09
# 97625  ex9dwo  1.580578e+09
# 97626  ex9egs  1.580578e+09
# 97627  ex9g78  1.580578e+09
#
#                                                    title  \
# 0      [AITA] I wrote an explanation in TIL and came ...
# 1                   [AITA] Threw my parent's donuts away
# 2            I told a goth girl she looked like a clown.
# 3      [AItA]: Argument I had with another redditor i...
# 4      [AITA] I let my story get a little long and bo...
# ...                                                  ...
# 97623  AITA for telling my sister she is being a spoi...
# 97624  AITA for telling my husband to f* off after he...
# 97625  AITA for attempting to keep my students out of...
# 97626  WIBTA if I left my brothers fate up to the state?
# 97627  WIBTA for rocking the boat at work because my ...
#
#                                                     body        edited  \
# 0      [Here is the post in question](http://www.redd...         False
# 1      My parents are diabetic, morbidly obese, and a...  1393290576.0
# 2                                            I was four.         False
# 3      http://www.reddit.com/r/HIMYM/comments/1vvfkq/...  1393286962.0
# 4                                                    NaN         False
# ...                                                  ...           ...
# 97623  My sister(17F) and I(15M) are white kids born ...  1580585457.0
# 97624  My husband (28M) and I (32F) are married for a...  1580584475.0
# 97625  Upfront apologies for formatting. I’m also try...         False
# 97626  A little back story my mom is a drug addict an...         False
# 97627  I’m a (23F) apprentice in the trades. I work o...         False
#
#                verdict  score  num_comments  is_asshole  \
# 0              asshole     52          13.0           1
# 1              asshole    140          27.0           1
# 2      not the asshole     74          15.0           0
# 3       everyone sucks     22           3.0           1
# 4      not the asshole      6           4.0           0
# ...                ...    ...           ...         ...
# 97623  not the asshole     16          23.0           0
# 97624  not the asshole   1373         304.0           0
# 97625  not the asshole      4          15.0           0
# 97626  not the asshole    280         140.0           0
# 97627  not the asshole      5          21.0           0
#
#                                                     text  age gender
# 0      [AITA] I wrote an explanation in TIL and came ...  NaN    NaN
# 1      [AITA] Threw my parent's donuts away My parent...  NaN    NaN
# 2      I told a goth girl she looked like a clown. I ...  NaN    NaN
# 3      [AItA]: Argument I had with another redditor i...  NaN    NaN
# 4                                                    NaN  NaN    NaN
# ...                                                  ...  ...    ...
# 97623  AITA for telling my sister she is being a spoi...   15      M
# 97624  AITA for telling my husband to f* off after he...   32      F
# 97625  AITA for attempting to keep my students out of...  NaN    NaN
# 97626  WIBTA if I left my brothers fate up to the sta...  NaN    NaN
# 97627  WIBTA for rocking the boat at work because my ...  NaN    NaN
#
# [97628 rows x 12 columns]

# %%
print(raw["age"].notnull().sum())
print(raw["gender"].notnull().sum())
# Out:
# 13957
# 9862

# %%
raw.to_csv("aita_processed.csv")

# %%
for index,row in raw.iterrows():
    if pd.isnull(raw.at[index,"age"]):
        if pd.notnull(raw.at[index,"gender"]) == True:
            print(index, row)

# %%
print(raw.columns)
# Out:
# Index(['id', 'timestamp', 'title', 'body', 'edited', 'verdict', 'score',
#        'num_comments', 'is_asshole', 'text'],
#       dtype='object')

# %%
print(raw)
# Out:
#            id     timestamp  \
# 0      1ytxov  1.393279e+09
# 1      1yu29c  1.393281e+09
# 2      1yu8hi  1.393285e+09
# 3      1yuc78  1.393287e+09
# 4      1yueqb  1.393288e+09
# ...       ...           ...
# 97623  ex94w5  1.580577e+09
# 97624  ex970f  1.580577e+09
# 97625  ex9dwo  1.580578e+09
# 97626  ex9egs  1.580578e+09
# 97627  ex9g78  1.580578e+09
#
#                                                    title  \
# 0      [AITA] I wrote an explanation in TIL and came ...
# 1                   [AITA] Threw my parent's donuts away
# 2            I told a goth girl she looked like a clown.
# 3      [AItA]: Argument I had with another redditor i...
# 4      [AITA] I let my story get a little long and bo...
# ...                                                  ...
# 97623  AITA for telling my sister she is being a spoi...
# 97624  AITA for telling my husband to f* off after he...
# 97625  AITA for attempting to keep my students out of...
# 97626  WIBTA if I left my brothers fate up to the state?
# 97627  WIBTA for rocking the boat at work because my ...
#
#                                                     body        edited  \
# 0      [Here is the post in question](http://www.redd...         False
# 1      My parents are diabetic, morbidly obese, and a...  1393290576.0
# 2                                            I was four.         False
# 3      http://www.reddit.com/r/HIMYM/comments/1vvfkq/...  1393286962.0
# 4                                                    NaN         False
# ...                                                  ...           ...
# 97623  My sister(17F) and I(15M) are white kids born ...  1580585457.0
# 97624  My husband (28M) and I (32F) are married for a...  1580584475.0
# 97625  Upfront apologies for formatting. I’m also try...         False
# 97626  A little back story my mom is a drug addict an...         False
# 97627  I’m a (23F) apprentice in the trades. I work o...         False
#
#                verdict  score  num_comments  is_asshole  \
# 0              asshole     52          13.0           1
# 1              asshole    140          27.0           1
# 2      not the asshole     74          15.0           0
# 3       everyone sucks     22           3.0           1
# 4      not the asshole      6           4.0           0
# ...                ...    ...           ...         ...
# 97623  not the asshole     16          23.0           0
# 97624  not the asshole   1373         304.0           0
# 97625  not the asshole      4          15.0           0
# 97626  not the asshole    280         140.0           0
# 97627  not the asshole      5          21.0           0
#
#                                                     text
# 0      [AITA] I wrote an explanation in TIL and came ...
# 1      [AITA] Threw my parent's donuts away My parent...
# 2      I told a goth girl she looked like a clown. I ...
# 3      [AItA]: Argument I had with another redditor i...
# 4                                                    NaN
# ...                                                  ...
# 97623  AITA for telling my sister she is being a spoi...
# 97624  AITA for telling my husband to f* off after he...
# 97625  AITA for attempting to keep my students out of...
# 97626  WIBTA if I left my brothers fate up to the sta...
# 97627  WIBTA for rocking the boat at work because my ...
#
# [97628 rows x 10 columns]
